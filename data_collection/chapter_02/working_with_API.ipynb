# %% [markdown]
# API -> Application programming Interface

# %%
import requests

# %%
URL = "https://jellybellywikiapi.onrender.com/api/Beans"

res = requests.get(URL)

# %%
j_data = res.json()

j_data
# Out:
# {'totalCount': 114,
#  'pageSize': 10,
#  'currentPage': 1,
#  'totalPages': 12,
#  'items': [{'beanId': 1,
#    'groupName': ['Jelly Belly Official Flavors', 'Soda Pop Shoppe® Flavors'],
#    'ingredients': ['Sugar',
#     'Corn Syrup',
#     'Modified Food Starch',
#     'Contains 2% Or Less Of The Following:',
#     'Citric Acid',
#     'Sodium Lactate',
#     'Natural & Artificial Flavor',
#     'Color Added',
#     'Yellow 5',
#     'Blue 1',
#     'Beeswax',
#     'Carnauba Wax',
#     "Confectioner'S Glaze"],
#    'flavorName': '7Up',
#    'description': 'The Refreshing And Crisp Flavor Of Lemon Lime Soda.',
#    'colorGroup': 'khaki',
#    'backgroundColor': '#CEDC91',
#    'imageUrl': 'https://cdn-tp1.mozu.com/9046-m1/cms/files/ab692677-5471-4863-91a8-659363ae4cc4',
#    'glutenFree': False,
#    'sugarFree': False,
#    'seasonal': False,
#    'kosher': True},
#   {'beanId': 2,
#    'groupName': ['Jelly Belly Official Flavors', 'Soda Pop Shoppe® Flavors'],
# ...

# %%
import pandas as pd

df = pd.json_normalize(j_data["items"])

df
# Out:
#    beanId                                          groupName  \
# 0       1  [Jelly Belly Official Flavors, Soda Pop Shoppe...
# 1       2  [Jelly Belly Official Flavors, Soda Pop Shoppe...
# 2       3  [Jelly Belly Official Flavors, Soda Pop Shoppe...
# 3       4                               [Superfruit Flavors]
# 4       5                              [Cold Stone® Flavors]
# 5       6                               [Superfruit Flavors]
# 6       7                     [Jelly Belly Official Flavors]
# 7       8   [Jelly Belly Official Flavors, Kids Mix Flavors]
# 8       9   [Jelly Belly Official Flavors, Kids Mix Flavors]
# 9      10  [Jelly Belly Official Flavors, Tropical Mix Fl...
#
#                                          ingredients  \
# 0  [Sugar, Corn Syrup, Modified Food Starch, Cont...
# 1  [Sugar, Corn Syrup, Modified Food Starch, Cont...
# 2  [Sugar, Corn Syrup, Modified Food Starch, Cont...
# 3  [Cane Sugar, Tapioca Syrup, Modified Food Star...
# ...
